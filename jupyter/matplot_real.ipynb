# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
import time

fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

def animate(i):
    xar = []
    yar = []
    for j in range(11):
        values = list(np.random.randint(10, size=2))
        #print values
        xar.append(values[0])
        yar.append(values[1])
        print xar, yar
        time.sleep(2)
        ax1.clear()
        ax1.plot(xar,yar)
ani = animation.FuncAnimation(fig, animate, interval=100)
plt.show()
# Out:
# [2] [5]
# [2, 7] [5, 0]
# [2, 7, 7] [5, 0, 6]
# [2, 7, 7, 0] [5, 0, 6, 5]
# [2, 7, 7, 0, 0] [5, 0, 6, 5, 8]
# [2, 7, 7, 0, 0, 4] [5, 0, 6, 5, 8, 6]
# [2, 7, 7, 0, 0, 4, 2] [5, 0, 6, 5, 8, 6, 9]
# [2, 7, 7, 0, 0, 4, 2, 4] [5, 0, 6, 5, 8, 6, 9, 6]
# [2, 7, 7, 0, 0, 4, 2, 4, 0] [5, 0, 6, 5, 8, 6, 9, 6, 3]
# [2, 7, 7, 0, 0, 4, 2, 4, 0, 6] [5, 0, 6, 5, 8, 6, 9, 6, 3, 3]
# [2, 7, 7, 0, 0, 4, 2, 4, 0, 6, 5] [5, 0, 6, 5, 8, 6, 9, 6, 3, 3, 7]
