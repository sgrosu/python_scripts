# %%
import matplotlib.pyplot as plt
from drawnow import drawnow
import numpy as np



def plotValues():
    plt.title('Number of queries per second')
    plt.grid(True)
    plt.ylabel('Values')
    plt.plot(values, 'rx-', label='values')
    plt.legend(loc='upper right')
i = 0
while i<100:
    values = np.random.randint(10, size=2)
    print values
    drawnow(plotValues)
    i+=1
# Out:
# [2 1]
# [4 8]
# [9 7]
# [6 2]
# [4 8]
# [9 8]
# [9 4]
# [7 9]
# [1 1]
# [6 5]
# [6 9]
# [4 6]
# [4 0]
# [7 6]
# [2 2]
# [9 9]
# [9 0]
# [4 1]
# [1 5]
# [7 4]
# [9 1]
# [8 4]
# [7 1]
# [1 0]
# [9 1]
# [4 9]
# [2 9]
# [0 5]
# [4 6]
# [3 4]
# [9 6]
# [4 6]
# [6 0]
# [4 2]
# [6 3]
# [5 7]
# [9 5]
# [6 9]
# [9 6]
# [9 5]
# [4 8]
# [2 9]
# [5 1]
# [9 1]
# [1 7]
# [3 8]
# [2 3]
# [0 4]
# [7 4]
# [6 3]
# [4 3]
# [7 4]
# [0 3]
# [4 8]
# [9 0]
# [5 3]
# [6 5]
# [8 7]
# [0 5]
# [8 1]
# [6 6]
# [4 7]
# [0 2]
# [1 1]
# [1 2]
# [5 7]
# [9 0]
# [9 6]
# [1 0]
# [5 8]
# [6 9]
# [3 4]
# [8 9]
# [6 1]
# [5 9]
# [9 5]
# [0 8]
# [0 0]
# [0 0]
# [3 0]
# [0 7]
# [4 7]
# [9 2]
# [9 6]
# [1 7]
# [9 8]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-189b0ace144f> in <module>()
#      15     values = np.random.randint(10, size=2)
#      16     print values
# ---> 17     drawnow(plotValues)
#      18     i+=1
#
# /home/sgrosu/anaconda2/lib/python2.7/site-packages/drawnow-0.71.2-py2.7.egg/drawnow/drawnow.pyc in drawnow(draw_fig, show_once, confirm, *argv, **kwargs)
#      55     """
#      56     # replace the current figure w/o opening new GUI
# ---> 57     plt.clf()
#      58     draw_fig(*argv, **kwargs)
#      59
#
# /home/sgrosu/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in clf()
#     671     Clear the current figure.
#     672     """
# --> 673     gcf().clf()
#     674
#     675
#
# /home/sgrosu/anaconda2/lib/python2.7/site-packages/matplotlib/figure.pyc in clf(self, keep_observers)
#    1064
#    1065         for ax in tuple(self.axes):  # Iterate over the copy.
# -> 1066             ax.cla()
#    1067             self.delaxes(ax)         # removes ax from self._axstack
#    1068
#
# /home/sgrosu/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in cla(self)
#     976         self.yaxis.cla()
#     977         for name, spine in six.iteritems(self.spines):
# --> 978             spine.cla()
#     979
#     980         self.ignore_existing_data_limits = True
#
# /home/sgrosu/anaconda2/lib/python2.7/site-packages/matplotlib/spines.pyc in cla(self)
#     168         self._position = None  # clear position
#     169         if self.axis is not None:
# --> 170             self.axis.cla()
#     171
#     172     def is_frame_like(self):
#
# /home/sgrosu/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in cla(self)
#     758         self._set_artist_props(self.label)
#     759
# --> 760         self.reset_ticks()
#     761
#     762         self.converter = None
#
# /home/sgrosu/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in reset_ticks(self)
#     772         cbook.popall(self.minorTicks)
#     773
# --> 774         self.majorTicks.extend([self._get_tick(major=True)])
#     775         self.minorTicks.extend([self._get_tick(major=False)])
#     776         self._lastNumMajorTicks = 1
#
# /home/sgrosu/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in _get_tick(self, major)
#    1727         else:
#    1728             tick_kw = self._minor_tick_kw
# -> 1729         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1730
#    1731     def _get_label(self):
#
# /home/sgrosu/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major)
#     149
#     150         self.tick1line = self._get_tick1line()
# --> 151         self.tick2line = self._get_tick2line()
#     152         self.gridline = self._get_gridline()
#     153
#
# /home/sgrosu/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in _get_tick2line(self)
#     434                           zorder=self._zorder)
#     435
# --> 436         l.set_transform(self.axes.get_xaxis_transform(which='tick2'))
#     437         self._set_artist_props(l)
#     438         return l
#
# /home/sgrosu/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in get_xaxis_transform(self, which)
#     707         elif which == 'tick2':
#     708             # for cartesian projection, this is top spine
# --> 709             return self.spines['top'].get_spine_transform()
#     710         else:
#     711             raise ValueError('unknown value for which')
#
# /home/sgrosu/anaconda2/lib/python2.7/site-packages/matplotlib/spines.pyc in get_spine_transform(self)
#     404     def get_spine_transform(self):
#     405         """get the spine transform"""
# --> 406         self._ensure_position_is_set()
#     407         what, how = self._spine_transform
#     408
#
# /home/sgrosu/anaconda2/lib/python2.7/site-packages/matplotlib/spines.pyc in _ensure_position_is_set(self)
#     150             # default position
#     151             self._position = ('outward', 0.0)  # in points
# --> 152             self.set_position(self._position)
#     153
#     154     def register_axis(self, axis):
#
# /home/sgrosu/anaconda2/lib/python2.7/site-packages/matplotlib/spines.pyc in set_position(self, position)
#     394
#     395         if self.axis is not None:
# --> 396             self.axis.reset_ticks()
#     397         self.stale = True
#     398
#
# /home/sgrosu/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in reset_ticks(self)
#     773
#     774         self.majorTicks.extend([self._get_tick(major=True)])
# --> 775         self.minorTicks.extend([self._get_tick(major=False)])
#     776         self._lastNumMajorTicks = 1
#     777         self._lastNumMinorTicks = 1
#
# /home/sgrosu/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in _get_tick(self, major)
#    1727         else:
#    1728             tick_kw = self._minor_tick_kw
# -> 1729         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1730
#    1731     def _get_label(self):
#
# /home/sgrosu/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major)
#     148         self.apply_tickdir(tickdir)
#     149
# --> 150         self.tick1line = self._get_tick1line()
#     151         self.tick2line = self._get_tick2line()
#     152         self.gridline = self._get_gridline()
#
# /home/sgrosu/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in _get_tick1line(self)
#     418                           linestyle='None', marker=self._tickmarkers[0],
#     419                           markersize=self._size,
# --> 420                           markeredgewidth=self._width, zorder=self._zorder)
#     421         l.set_transform(self.axes.get_xaxis_transform(which='tick1'))
#     422         self._set_artist_props(l)
#
# /home/sgrosu/anaconda2/lib/python2.7/site-packages/matplotlib/lines.pyc in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     402         self._color = None
#     403         self.set_color(color)
# --> 404         self._marker = MarkerStyle()
#     405         self.set_marker(marker)
#     406
#
# /home/sgrosu/anaconda2/lib/python2.7/site-packages/matplotlib/markers.pyc in __init__(self, marker, fillstyle)
#     184         # _recache() in set_marker.
#     185         self._fillstyle = fillstyle
# --> 186         self.set_marker(marker)
#     187         self.set_fillstyle(fillstyle)
#     188
#
# /home/sgrosu/anaconda2/lib/python2.7/site-packages/matplotlib/markers.pyc in set_marker(self, marker)
#     268
#     269         self._marker = marker
# --> 270         self._recache()
#     271
#     272     def get_path(self):
#
# /home/sgrosu/anaconda2/lib/python2.7/site-packages/matplotlib/markers.pyc in _recache(self)
#     198
#     199     def _recache(self):
# --> 200         self._path = Path(np.empty((0, 2)))
#     201         self._transform = IdentityTransform()
#     202         self._alt_path = None
#
# /home/sgrosu/anaconda2/lib/python2.7/site-packages/matplotlib/path.pyc in __init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     160         self._codes = codes
#     161         self._interpolation_steps = _interpolation_steps
# --> 162         self._update_values()
#     163
#     164         if readonly:
#
# /home/sgrosu/anaconda2/lib/python2.7/site-packages/matplotlib/path.pyc in _update_values(self)
#     217         )
#     218         self._simplify_threshold = rcParams['path.simplify_threshold']
# --> 219         self._has_nonfinite = not np.isfinite(self._vertices).all()
#     220
#     221     @property
#
# /home/sgrosu/anaconda2/lib/python2.7/site-packages/numpy/core/_methods.pyc in _all(a, axis, dtype, out, keepdims)
#      39
#      40 def _all(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 41     return umr_all(a, axis, dtype, out, keepdims)
#      42
#      43 def _count_reduce_items(arr, axis):
#
# KeyboardInterrupt:
